# %%
import sys, os
PROJECT_ROOT = r"D:\bhermosi\chestxsim-project"   # <- adjust to your real path
SRC = os.path.join(PROJECT_ROOT, "src")
if SRC not in sys.path:
    sys.path.insert(0, SRC)
from chestxsim.core import geometries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 if SRC not in sys.path:
#       5     sys.path.insert(0, SRC)
# ----> 6 from chestxsim.core import geometries
#
# ImportError: cannot import name 'geometries' from 'chestxsim.core' (unknown location)
